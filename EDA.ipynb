# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

# %%
TRAIN_PATH = './Data/Train'
TEST_PATH = './Data/Test'

# %%
train_walk = os.walk(TRAIN_PATH)
main_dir_path, _, rle_path = next(train_walk)
dir_im_path, _, train_im_path = next(train_walk)
dir_mask_path, _, train_mask_path = next(train_walk)

# %%
train_df = pd.DataFrame()
train_df['id'] = [im_p.split('.')[0] for im_p in train_im_path]
train_df['im_paths'] = [os.path.join(dir_im_path, im_p) for im_p in train_im_path]
train_df['mask_paths'] = [os.path.join(dir_mask_path, m_p) for m_p in train_mask_path]
rle_df = pd.read_csv(os.path.join(main_dir_path, rle_path[0]))
train_df = train_df.merge(rle_df, on='id', how='left')

# %%
train_df
# rle.shape
# Out:
#               id                            im_paths  \
# 0     13483cd62a  ./Data/Train/images/13483cd62a.png
# 1     35f3cb48d6  ./Data/Train/images/35f3cb48d6.png
# 2     3e87545802  ./Data/Train/images/3e87545802.png
# 3     87cf2c6542  ./Data/Train/images/87cf2c6542.png
# 4     a2a9c0c00a  ./Data/Train/images/a2a9c0c00a.png
# ...          ...                                 ...
# 3995  c1503fb0ec  ./Data/Train/images/c1503fb0ec.png
# 3996  f4638e7428  ./Data/Train/images/f4638e7428.png
# 3997  64bfdd0b9a  ./Data/Train/images/64bfdd0b9a.png
# 3998  6b95bc6c5f  ./Data/Train/images/6b95bc6c5f.png
# 3999  9472731dfd  ./Data/Train/images/9472731dfd.png
#
#                              mask_paths    z
# 0     ./Data/Train/masks/13483cd62a.png  472
# 1     ./Data/Train/masks/35f3cb48d6.png  415
# 2     ./Data/Train/masks/3e87545802.png  754
# 3     ./Data/Train/masks/87cf2c6542.png  670
# 4     ./Data/Train/masks/a2a9c0c00a.png  796
# ...                                 ...  ...
# 3995  ./Data/Train/masks/c1503fb0ec.png  480
# 3996  ./Data/Train/masks/f4638e7428.png  257
# 3997  ./Data/Train/masks/64bfdd0b9a.png  600
# 3998  ./Data/Train/masks/6b95bc6c5f.png  198
# 3999  ./Data/Train/masks/9472731dfd.png  568
#
# [4000 rows x 4 columns]
